# %%
import sys
sys.path.append('../../..')

import numpy as np
import random
import pandas as pd
import time
from matplotlib import pyplot as plt

from core.points import *
from core.ranges import *
from algorithms.fairness.fair_epsnet import *
from core.ranges import get_range_space
from core.verification import is_fair_epsnet

# %% [markdown]
# Sampling method:

# %%
def report_fair_epsnet_sample(n, m, eps, ratios, c1, dim):
    success_prob = 0.9
    
    
    color_counts = []
    for ratio in ratios:
        color_counts.append(int(n * ratio))
    
    points = []
    for i, count in enumerate(color_counts):
        points += [Point(point=[random.uniform(0, 1), random.uniform(0, 1)], color=i) for _ in range(count)]
    
    ranges = []
    for _ in range(m):
        # Generate a random normal vector in R^d
        normal = [random.uniform(-1, 1) for _ in range(dim)]
        
        # Calculate the range of possible dot products with the [0, 1]^d hypercube
        min_dot = sum(min(0, n) for n in normal)  # Minimum dot product with [0, 1]^d
        max_dot = sum(max(0, n) for n in normal)  # Maximum dot product with [0, 1]^d
        
        # Choose an offset within the range [min_dot, max_dot] to ensure intersection
        offset = random.uniform(min_dot, max_dot)
        
        # Create a HalfspaceRange object
        halfspace = HalfspaceRange(normal=normal, offset=offset)
        ranges.append(halfspace)
        
    rangespace = get_range_space(points, ranges)
    vc = dim + 1

    heavy_ranges = []
    for r in rangespace:
        if len(r) >= n * eps:
            heavy_ranges.append(r)
            
    print(f"n: {n}, m: {m}, vc: {vc}, epsilon: {eps}, number of heavy ranges: {len(heavy_ranges)}")

    # for _ in range(10):
    start = time.time()
    epsnet = build_fair_epsnet_sample(
        points=points,
        rangespace=rangespace,
        vc=vc,
        epsilon=eps,
        fairconfig=FairConfig(k=len(ratios), fairness=FairnessMeasure.DP),
        success_prob=success_prob,
        weights=None,
        c1=c1
    )
    end = time.time()

    print(f"Number of points in epsnet: {len(epsnet)}, time taken: {end - start:.6f} seconds")

    success = is_fair_epsnet(epsnet=epsnet, rangespace=rangespace, epsilon=eps, points=points)
    print(f"Success: {success}")  # Verify the eps-net
    
    return (n, m, 
            success_prob, 
            eps, 
            end - start, 
            success, 
            len(heavy_ranges), 
            len([p for p in epsnet if p.color == 0]), len([p for p in epsnet if p.color == 1]),
            len(ratios), # k
            ratios,
            [len([p for p in epsnet if p.color == i]) for i in range(len(ratios))], # color counts
            )

# %%
report_fair_epsnet_sample(2**10, 2**10, 0.6, [0.5, 0.5], 1/2, 32)  # Example usage

# %%
n_values = [2**9, 2**10, 2**11, 2**12]
m_values = [2**9, 2**10, 2**11, 2**12]
eps_values = [0.6]
dims = [4, 8, 16, 32]
rates = [
    [0.5, 0.5]
]

aggregated_results = {
    "n": [],
    "m": [],
    "prob": [],
    "eps": [],
    "time": [],
    "success": [],
    "heavy_ranges": [],
    "tries": [],
    "red_points": [],
    "blue_points": [],
    "k": [],
    "ratios": [],
    "counts": [],
    "dim": []
}

for n in n_values:
    for m in m_values:
        for eps in eps_values:
            for dim in dims:
                ratio = rates[0]
                tries = 20
                print(f"Running for n={n}, m={m}, eps={eps}, dim={dim}")
                result = report_fair_epsnet_sample(n, m, eps, ratio, c1=1/2, dim=dim)
                while not result[5] and tries > 0:
                    print("Retrying...")
                    result = report_fair_epsnet_sample(n, m, eps, ratio, c1=1/2, dim=dim)
                    tries -= 1
                
                aggregated_results["n"].append(result[0])
                aggregated_results["m"].append(result[1])
                aggregated_results["prob"].append(result[2])
                aggregated_results["eps"].append(result[3])
                aggregated_results["time"].append(result[4])
                aggregated_results["success"].append(result[5])
                aggregated_results["heavy_ranges"].append(result[6])
                aggregated_results["tries"].append(10 - tries)
                aggregated_results["red_points"].append(result[7])
                aggregated_results["blue_points"].append(result[8])
                aggregated_results["k"].append(result[9])
                aggregated_results["ratios"].append(result[10])
                aggregated_results["counts"].append(result[11])
                aggregated_results["dim"].append(dim)

result = pd.DataFrame(aggregated_results)
# Out:
# Running for n=512, m=512, eps=0.6, dim=4
# n: 512, m: 512, vc: 5, epsilon: 0.6, number of heavy ranges: 240
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 165
# 	[_augment_epsnet] Color 1: 151
# [_augment_epsnet] Color 0 to add: 72
# [_augment_epsnet] Color 1 to add: 86
# Number of points in epsnet: 474, time taken: 0.001031 seconds
# Success: True
# Running for n=512, m=512, eps=0.6, dim=8
# n: 512, m: 512, vc: 9, epsilon: 0.6, number of heavy ranges: 237
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 253
# 	[_augment_epsnet] Color 1: 259
# [_augment_epsnet] Color 0 to add: 131
# [_augment_epsnet] Color 1 to add: 125
# Number of points in epsnet: 696, time taken: 0.001402 seconds
# Success: True
# Running for n=512, m=512, eps=0.6, dim=16
# n: 512, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 254
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 242
# 	[_augment_epsnet] Color 1: 270
# [_augment_epsnet] Color 0 to add: 142
# [_augment_epsnet] Color 1 to add: 114
# Number of points in epsnet: 693, time taken: 0.001318 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 241
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 256
# 	[_augment_epsnet] Color 1: 256
# [_augment_epsnet] Color 0 to add: 128
# [_augment_epsnet] Color 1 to add: 128
# Number of points in epsnet: 699, time taken: 0.001392 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 242
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 256
# 	[_augment_epsnet] Color 1: 256
# [_augment_epsnet] Color 0 to add: 128
# [_augment_epsnet] Color 1 to add: 128
# Number of points in epsnet: 703, time taken: 0.001297 seconds
# Success: True
# Running for n=512, m=512, eps=0.6, dim=32
# n: 512, m: 512, vc: 33, epsilon: 0.6, number of heavy ranges: 249
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 240
# 	[_augment_epsnet] Color 1: 272
# [_augment_epsnet] Color 0 to add: 144
# [_augment_epsnet] Color 1 to add: 112
# Number of points in epsnet: 688, time taken: 0.001379 seconds
# Success: True
# Running for n=512, m=1024, eps=0.6, dim=4
# n: 512, m: 1024, vc: 5, epsilon: 0.6, number of heavy ranges: 462
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 150
# 	[_augment_epsnet] Color 1: 166
# [_augment_epsnet] Color 0 to add: 87
# [_augment_epsnet] Color 1 to add: 71
# Number of points in epsnet: 474, time taken: 0.001068 seconds
# Success: True
# Running for n=512, m=1024, eps=0.6, dim=8
# n: 512, m: 1024, vc: 9, epsilon: 0.6, number of heavy ranges: 493
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 263
# 	[_augment_epsnet] Color 1: 249
# [_augment_epsnet] Color 0 to add: 121
# [_augment_epsnet] Color 1 to add: 135
# Number of points in epsnet: 703, time taken: 0.001373 seconds
# Success: True
# Running for n=512, m=1024, eps=0.6, dim=16
# n: 512, m: 1024, vc: 17, epsilon: 0.6, number of heavy ranges: 500
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 263
# 	[_augment_epsnet] Color 1: 249
# [_augment_epsnet] Color 0 to add: 121
# [_augment_epsnet] Color 1 to add: 135
# Number of points in epsnet: 699, time taken: 0.001407 seconds
# Success: True
# Running for n=512, m=1024, eps=0.6, dim=32
# n: 512, m: 1024, vc: 33, epsilon: 0.6, number of heavy ranges: 513
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 280
# 	[_augment_epsnet] Color 1: 232
# [_augment_epsnet] Color 0 to add: 104
# [_augment_epsnet] Color 1 to add: 152
# Number of points in epsnet: 712, time taken: 0.001425 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 1024, vc: 33, epsilon: 0.6, number of heavy ranges: 499
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 258
# 	[_augment_epsnet] Color 1: 254
# [_augment_epsnet] Color 0 to add: 126
# [_augment_epsnet] Color 1 to add: 130
# Number of points in epsnet: 699, time taken: 0.001356 seconds
# Success: True
# Running for n=512, m=2048, eps=0.6, dim=4
# n: 512, m: 2048, vc: 5, epsilon: 0.6, number of heavy ranges: 919
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 148
# 	[_augment_epsnet] Color 1: 168
# [_augment_epsnet] Color 0 to add: 89
# [_augment_epsnet] Color 1 to add: 69
# Number of points in epsnet: 474, time taken: 0.001094 seconds
# Success: True
# Running for n=512, m=2048, eps=0.6, dim=8
# n: 512, m: 2048, vc: 9, epsilon: 0.6, number of heavy ranges: 954
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 242
# 	[_augment_epsnet] Color 1: 270
# [_augment_epsnet] Color 0 to add: 142
# [_augment_epsnet] Color 1 to add: 114
# Number of points in epsnet: 698, time taken: 0.001411 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 2048, vc: 9, epsilon: 0.6, number of heavy ranges: 1001
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 236
# 	[_augment_epsnet] Color 1: 276
# [_augment_epsnet] Color 0 to add: 148
# [_augment_epsnet] Color 1 to add: 108
# Number of points in epsnet: 705, time taken: 0.001423 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 2048, vc: 9, epsilon: 0.6, number of heavy ranges: 995
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 245
# 	[_augment_epsnet] Color 1: 267
# [_augment_epsnet] Color 0 to add: 139
# [_augment_epsnet] Color 1 to add: 117
# Number of points in epsnet: 710, time taken: 0.001450 seconds
# Success: True
# Running for n=512, m=2048, eps=0.6, dim=16
# n: 512, m: 2048, vc: 17, epsilon: 0.6, number of heavy ranges: 987
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 258
# 	[_augment_epsnet] Color 1: 254
# [_augment_epsnet] Color 0 to add: 126
# [_augment_epsnet] Color 1 to add: 130
# Number of points in epsnet: 693, time taken: 0.001395 seconds
# Success: True
# Running for n=512, m=2048, eps=0.6, dim=32
# n: 512, m: 2048, vc: 33, epsilon: 0.6, number of heavy ranges: 1013
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 266
# 	[_augment_epsnet] Color 1: 246
# [_augment_epsnet] Color 0 to add: 118
# [_augment_epsnet] Color 1 to add: 138
# Number of points in epsnet: 699, time taken: 0.001424 seconds
# Success: True
# Running for n=512, m=4096, eps=0.6, dim=4
# n: 512, m: 4096, vc: 5, epsilon: 0.6, number of heavy ranges: 1920
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 153
# 	[_augment_epsnet] Color 1: 163
# [_augment_epsnet] Color 0 to add: 84
# [_augment_epsnet] Color 1 to add: 74
# Number of points in epsnet: 474, time taken: 0.001102 seconds
# Success: True
# Running for n=512, m=4096, eps=0.6, dim=8
# n: 512, m: 4096, vc: 9, epsilon: 0.6, number of heavy ranges: 1947
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 251
# 	[_augment_epsnet] Color 1: 261
# [_augment_epsnet] Color 0 to add: 133
# [_augment_epsnet] Color 1 to add: 123
# Number of points in epsnet: 695, time taken: 0.001375 seconds
# Success: True
# Running for n=512, m=4096, eps=0.6, dim=16
# n: 512, m: 4096, vc: 17, epsilon: 0.6, number of heavy ranges: 2044
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 248
# 	[_augment_epsnet] Color 1: 264
# [_augment_epsnet] Color 0 to add: 136
# [_augment_epsnet] Color 1 to add: 120
# Number of points in epsnet: 714, time taken: 0.001426 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 4096, vc: 17, epsilon: 0.6, number of heavy ranges: 1987
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 257
# 	[_augment_epsnet] Color 1: 255
# [_augment_epsnet] Color 0 to add: 127
# [_augment_epsnet] Color 1 to add: 129
# Number of points in epsnet: 711, time taken: 0.001428 seconds
# Success: True
# Running for n=512, m=4096, eps=0.6, dim=32
# n: 512, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 2040
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 251
# 	[_augment_epsnet] Color 1: 261
# [_augment_epsnet] Color 0 to add: 133
# [_augment_epsnet] Color 1 to add: 123
# Number of points in epsnet: 694, time taken: 0.001310 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 2008
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 253
# 	[_augment_epsnet] Color 1: 259
# [_augment_epsnet] Color 0 to add: 131
# [_augment_epsnet] Color 1 to add: 125
# Number of points in epsnet: 688, time taken: 0.001417 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 2012
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 277
# 	[_augment_epsnet] Color 1: 235
# [_augment_epsnet] Color 0 to add: 107
# [_augment_epsnet] Color 1 to add: 149
# Number of points in epsnet: 712, time taken: 0.001446 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 2063
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 232
# 	[_augment_epsnet] Color 1: 280
# [_augment_epsnet] Color 0 to add: 152
# [_augment_epsnet] Color 1 to add: 104
# Number of points in epsnet: 707, time taken: 0.001335 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 512, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 1996
# [build_fair_epsnet_sample] epsnet size m: 512, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 246
# 	[_augment_epsnet] Color 1: 266
# [_augment_epsnet] Color 0 to add: 138
# [_augment_epsnet] Color 1 to add: 118
# Number of points in epsnet: 700, time taken: 0.001458 seconds
# Success: True
# Running for n=1024, m=512, eps=0.6, dim=4
# n: 1024, m: 512, vc: 5, epsilon: 0.6, number of heavy ranges: 250
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 164
# 	[_augment_epsnet] Color 1: 152
# [_augment_epsnet] Color 0 to add: 73
# [_augment_epsnet] Color 1 to add: 85
# Number of points in epsnet: 474, time taken: 0.002168 seconds
# Success: True
# Running for n=1024, m=512, eps=0.6, dim=8
# n: 1024, m: 512, vc: 9, epsilon: 0.6, number of heavy ranges: 248
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 289
# 	[_augment_epsnet] Color 1: 280
# [_augment_epsnet] Color 0 to add: 137
# [_augment_epsnet] Color 1 to add: 146
# Number of points in epsnet: 852, time taken: 0.003220 seconds
# Success: True
# Running for n=1024, m=512, eps=0.6, dim=16
# n: 1024, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 260
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 495
# 	[_augment_epsnet] Color 1: 529
# [_augment_epsnet] Color 0 to add: 273
# [_augment_epsnet] Color 1 to add: 239
# Number of points in epsnet: 1383, time taken: 0.004428 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 1024, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 246
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 525
# 	[_augment_epsnet] Color 1: 499
# [_augment_epsnet] Color 0 to add: 243
# [_augment_epsnet] Color 1 to add: 269
# Number of points in epsnet: 1382, time taken: 0.004267 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 1024, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 250
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 538
# 	[_augment_epsnet] Color 1: 486
# [_augment_epsnet] Color 0 to add: 230
# [_augment_epsnet] Color 1 to add: 282
# Number of points in epsnet: 1395, time taken: 0.004489 seconds
# Not a fair eps-net!
# Success: False
# Retrying...
# n: 1024, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 255
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 517
# 	[_augment_epsnet] Color 1: 507
# [_augment_epsnet] Color 0 to add: 251
# [_augment_epsnet] Color 1 to add: 261
# Number of points in epsnet: 1393, time taken: 0.004507 seconds
# Success: True
# Running for n=1024, m=512, eps=0.6, dim=32
# n: 1024, m: 512, vc: 33, epsilon: 0.6, number of heavy ranges: 255
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 529
# 	[_augment_epsnet] Color 1: 495
# [_augment_epsnet] Color 0 to add: 239
# [_augment_epsnet] Color 1 to add: 273
# Number of points in epsnet: 1407, time taken: 0.004615 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.6, dim=4
# n: 1024, m: 1024, vc: 5, epsilon: 0.6, number of heavy ranges: 483
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 150
# 	[_augment_epsnet] Color 1: 166
# [_augment_epsnet] Color 0 to add: 87
# [_augment_epsnet] Color 1 to add: 71
# Number of points in epsnet: 474, time taken: 0.002219 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.6, dim=8
# n: 1024, m: 1024, vc: 9, epsilon: 0.6, number of heavy ranges: 506
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 299
# 	[_augment_epsnet] Color 1: 270
# [_augment_epsnet] Color 0 to add: 127
# [_augment_epsnet] Color 1 to add: 156
# Number of points in epsnet: 852, time taken: 0.003289 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.6, dim=16
# n: 1024, m: 1024, vc: 17, epsilon: 0.6, number of heavy ranges: 508
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 505
# 	[_augment_epsnet] Color 1: 519
# [_augment_epsnet] Color 0 to add: 263
# [_augment_epsnet] Color 1 to add: 249
# Number of points in epsnet: 1406, time taken: 0.004661 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.6, dim=32
# n: 1024, m: 1024, vc: 33, epsilon: 0.6, number of heavy ranges: 495
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 504
# 	[_augment_epsnet] Color 1: 520
# [_augment_epsnet] Color 0 to add: 264
# [_augment_epsnet] Color 1 to add: 248
# Number of points in epsnet: 1408, time taken: 0.004561 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.6, dim=4
# n: 1024, m: 2048, vc: 5, epsilon: 0.6, number of heavy ranges: 926
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 157
# 	[_augment_epsnet] Color 1: 159
# [_augment_epsnet] Color 0 to add: 80
# [_augment_epsnet] Color 1 to add: 78
# Number of points in epsnet: 474, time taken: 0.002182 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.6, dim=8
# n: 1024, m: 2048, vc: 9, epsilon: 0.6, number of heavy ranges: 1004
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 274
# 	[_augment_epsnet] Color 1: 295
# [_augment_epsnet] Color 0 to add: 152
# [_augment_epsnet] Color 1 to add: 131
# Number of points in epsnet: 852, time taken: 0.003274 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.6, dim=16
# n: 1024, m: 2048, vc: 17, epsilon: 0.6, number of heavy ranges: 1000
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 515
# 	[_augment_epsnet] Color 1: 509
# [_augment_epsnet] Color 0 to add: 253
# [_augment_epsnet] Color 1 to add: 259
# Number of points in epsnet: 1407, time taken: 0.004713 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.6, dim=32
# n: 1024, m: 2048, vc: 33, epsilon: 0.6, number of heavy ranges: 1052
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 519
# 	[_augment_epsnet] Color 1: 505
# [_augment_epsnet] Color 0 to add: 249
# [_augment_epsnet] Color 1 to add: 263
# Number of points in epsnet: 1395, time taken: 0.004482 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.6, dim=4
# n: 1024, m: 4096, vc: 5, epsilon: 0.6, number of heavy ranges: 1936
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 146
# 	[_augment_epsnet] Color 1: 170
# [_augment_epsnet] Color 0 to add: 91
# [_augment_epsnet] Color 1 to add: 67
# Number of points in epsnet: 474, time taken: 0.002234 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.6, dim=8
# n: 1024, m: 4096, vc: 9, epsilon: 0.6, number of heavy ranges: 1912
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 290
# 	[_augment_epsnet] Color 1: 279
# [_augment_epsnet] Color 0 to add: 136
# [_augment_epsnet] Color 1 to add: 147
# Number of points in epsnet: 852, time taken: 0.003193 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.6, dim=16
# n: 1024, m: 4096, vc: 17, epsilon: 0.6, number of heavy ranges: 2000
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 509
# 	[_augment_epsnet] Color 1: 515
# [_augment_epsnet] Color 0 to add: 259
# [_augment_epsnet] Color 1 to add: 253
# Number of points in epsnet: 1405, time taken: 0.004710 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.6, dim=32
# n: 1024, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 1994
# [build_fair_epsnet_sample] epsnet size m: 1024, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 512
# 	[_augment_epsnet] Color 1: 512
# [_augment_epsnet] Color 0 to add: 256
# [_augment_epsnet] Color 1 to add: 256
# Number of points in epsnet: 1388, time taken: 0.004529 seconds
# Success: True
# Running for n=2048, m=512, eps=0.6, dim=4
# n: 2048, m: 512, vc: 5, epsilon: 0.6, number of heavy ranges: 238
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 143
# 	[_augment_epsnet] Color 1: 173
# [_augment_epsnet] Color 0 to add: 94
# [_augment_epsnet] Color 1 to add: 64
# Number of points in epsnet: 474, time taken: 0.004491 seconds
# Success: True
# Running for n=2048, m=512, eps=0.6, dim=8
# n: 2048, m: 512, vc: 9, epsilon: 0.6, number of heavy ranges: 251
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 283
# 	[_augment_epsnet] Color 1: 286
# [_augment_epsnet] Color 0 to add: 143
# [_augment_epsnet] Color 1 to add: 140
# Number of points in epsnet: 852, time taken: 0.007047 seconds
# Success: True
# Running for n=2048, m=512, eps=0.6, dim=16
# n: 2048, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 248
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 530
# 	[_augment_epsnet] Color 1: 544
# [_augment_epsnet] Color 0 to add: 275
# [_augment_epsnet] Color 1 to add: 261
# Number of points in epsnet: 1610, time taken: 0.011405 seconds
# Success: True
# Running for n=2048, m=512, eps=0.6, dim=32
# n: 2048, m: 512, vc: 33, epsilon: 0.6, number of heavy ranges: 232
# [build_fair_epsnet_sample] epsnet size m: 2048, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 1003
# 	[_augment_epsnet] Color 1: 1045
# [_augment_epsnet] Color 0 to add: 533
# [_augment_epsnet] Color 1 to add: 491
# Number of points in epsnet: 2772, time taken: 0.016833 seconds
# Success: True
# Running for n=2048, m=1024, eps=0.6, dim=4
# n: 2048, m: 1024, vc: 5, epsilon: 0.6, number of heavy ranges: 457
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 172
# 	[_augment_epsnet] Color 1: 144
# [_augment_epsnet] Color 0 to add: 65
# [_augment_epsnet] Color 1 to add: 93
# Number of points in epsnet: 474, time taken: 0.004113 seconds
# Success: True
# Running for n=2048, m=1024, eps=0.6, dim=8
# n: 2048, m: 1024, vc: 9, epsilon: 0.6, number of heavy ranges: 524
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 280
# 	[_augment_epsnet] Color 1: 289
# [_augment_epsnet] Color 0 to add: 146
# [_augment_epsnet] Color 1 to add: 137
# Number of points in epsnet: 852, time taken: 0.007184 seconds
# Success: True
# Running for n=2048, m=1024, eps=0.6, dim=16
# n: 2048, m: 1024, vc: 17, epsilon: 0.6, number of heavy ranges: 518
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 552
# 	[_augment_epsnet] Color 1: 522
# [_augment_epsnet] Color 0 to add: 253
# [_augment_epsnet] Color 1 to add: 283
# Number of points in epsnet: 1610, time taken: 0.011575 seconds
# Success: True
# Running for n=2048, m=1024, eps=0.6, dim=32
# n: 2048, m: 1024, vc: 33, epsilon: 0.6, number of heavy ranges: 514
# [build_fair_epsnet_sample] epsnet size m: 2048, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 1062
# 	[_augment_epsnet] Color 1: 986
# [_augment_epsnet] Color 0 to add: 474
# [_augment_epsnet] Color 1 to add: 550
# Number of points in epsnet: 2789, time taken: 0.016864 seconds
# Success: True
# Running for n=2048, m=2048, eps=0.6, dim=4
# n: 2048, m: 2048, vc: 5, epsilon: 0.6, number of heavy ranges: 942
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 150
# 	[_augment_epsnet] Color 1: 166
# [_augment_epsnet] Color 0 to add: 87
# [_augment_epsnet] Color 1 to add: 71
# Number of points in epsnet: 474, time taken: 0.004318 seconds
# Success: True
# Running for n=2048, m=2048, eps=0.6, dim=8
# n: 2048, m: 2048, vc: 9, epsilon: 0.6, number of heavy ranges: 1003
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 297
# 	[_augment_epsnet] Color 1: 272
# [_augment_epsnet] Color 0 to add: 129
# [_augment_epsnet] Color 1 to add: 154
# Number of points in epsnet: 852, time taken: 0.007118 seconds
# Success: True
# Running for n=2048, m=2048, eps=0.6, dim=16
# n: 2048, m: 2048, vc: 17, epsilon: 0.6, number of heavy ranges: 983
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 575
# 	[_augment_epsnet] Color 1: 499
# [_augment_epsnet] Color 0 to add: 230
# [_augment_epsnet] Color 1 to add: 306
# Number of points in epsnet: 1610, time taken: 0.011612 seconds
# Success: True
# Running for n=2048, m=2048, eps=0.6, dim=32
# n: 2048, m: 2048, vc: 33, epsilon: 0.6, number of heavy ranges: 1014
# [build_fair_epsnet_sample] epsnet size m: 2048, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 988
# 	[_augment_epsnet] Color 1: 1060
# [_augment_epsnet] Color 0 to add: 548
# [_augment_epsnet] Color 1 to add: 476
# Number of points in epsnet: 2793, time taken: 0.016685 seconds
# Success: True
# Running for n=2048, m=4096, eps=0.6, dim=4
# n: 2048, m: 4096, vc: 5, epsilon: 0.6, number of heavy ranges: 1937
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 162
# 	[_augment_epsnet] Color 1: 154
# [_augment_epsnet] Color 0 to add: 75
# [_augment_epsnet] Color 1 to add: 83
# Number of points in epsnet: 474, time taken: 0.004290 seconds
# Success: True
# Running for n=2048, m=4096, eps=0.6, dim=8
# n: 2048, m: 4096, vc: 9, epsilon: 0.6, number of heavy ranges: 1972
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 291
# 	[_augment_epsnet] Color 1: 278
# [_augment_epsnet] Color 0 to add: 135
# [_augment_epsnet] Color 1 to add: 148
# Number of points in epsnet: 852, time taken: 0.007148 seconds
# Success: True
# Running for n=2048, m=4096, eps=0.6, dim=16
# n: 2048, m: 4096, vc: 17, epsilon: 0.6, number of heavy ranges: 1988
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 518
# 	[_augment_epsnet] Color 1: 556
# [_augment_epsnet] Color 0 to add: 287
# [_augment_epsnet] Color 1 to add: 249
# Number of points in epsnet: 1610, time taken: 0.011562 seconds
# Success: True
# Running for n=2048, m=4096, eps=0.6, dim=32
# n: 2048, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 1992
# [build_fair_epsnet_sample] epsnet size m: 2048, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 1048
# 	[_augment_epsnet] Color 1: 1000
# [_augment_epsnet] Color 0 to add: 488
# [_augment_epsnet] Color 1 to add: 536
# Number of points in epsnet: 2796, time taken: 0.016946 seconds
# Success: True
# Running for n=4096, m=512, eps=0.6, dim=4
# n: 4096, m: 512, vc: 5, epsilon: 0.6, number of heavy ranges: 246
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 165
# 	[_augment_epsnet] Color 1: 151
# [_augment_epsnet] Color 0 to add: 72
# [_augment_epsnet] Color 1 to add: 86
# Number of points in epsnet: 474, time taken: 0.009103 seconds
# Success: True
# Running for n=4096, m=512, eps=0.6, dim=8
# n: 4096, m: 512, vc: 9, epsilon: 0.6, number of heavy ranges: 239
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 280
# 	[_augment_epsnet] Color 1: 289
# [_augment_epsnet] Color 0 to add: 146
# [_augment_epsnet] Color 1 to add: 137
# Number of points in epsnet: 852, time taken: 0.015105 seconds
# Success: True
# Running for n=4096, m=512, eps=0.6, dim=16
# n: 4096, m: 512, vc: 17, epsilon: 0.6, number of heavy ranges: 251
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 559
# 	[_augment_epsnet] Color 1: 515
# [_augment_epsnet] Color 0 to add: 246
# [_augment_epsnet] Color 1 to add: 290
# Number of points in epsnet: 1610, time taken: 0.025552 seconds
# Success: True
# Running for n=4096, m=512, eps=0.6, dim=32
# n: 4096, m: 512, vc: 33, epsilon: 0.6, number of heavy ranges: 265
# [build_fair_epsnet_sample] epsnet size m: 2085, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 1028
# 	[_augment_epsnet] Color 1: 1057
# [_augment_epsnet] Color 0 to add: 535
# [_augment_epsnet] Color 1 to add: 506
# Number of points in epsnet: 3126, time taken: 0.061443 seconds
# Success: True
# Running for n=4096, m=1024, eps=0.6, dim=4
# n: 4096, m: 1024, vc: 5, epsilon: 0.6, number of heavy ranges: 495
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 163
# 	[_augment_epsnet] Color 1: 153
# [_augment_epsnet] Color 0 to add: 74
# [_augment_epsnet] Color 1 to add: 84
# Number of points in epsnet: 474, time taken: 0.033145 seconds
# Success: True
# Running for n=4096, m=1024, eps=0.6, dim=8
# n: 4096, m: 1024, vc: 9, epsilon: 0.6, number of heavy ranges: 497
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 304
# 	[_augment_epsnet] Color 1: 265
# [_augment_epsnet] Color 0 to add: 122
# [_augment_epsnet] Color 1 to add: 161
# Number of points in epsnet: 852, time taken: 0.037113 seconds
# Success: True
# Running for n=4096, m=1024, eps=0.6, dim=16
# n: 4096, m: 1024, vc: 17, epsilon: 0.6, number of heavy ranges: 505
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 545
# 	[_augment_epsnet] Color 1: 529
# [_augment_epsnet] Color 0 to add: 260
# [_augment_epsnet] Color 1 to add: 276
# Number of points in epsnet: 1610, time taken: 0.043891 seconds
# Success: True
# Running for n=4096, m=1024, eps=0.6, dim=32
# n: 4096, m: 1024, vc: 33, epsilon: 0.6, number of heavy ranges: 494
# [build_fair_epsnet_sample] epsnet size m: 2085, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 1018
# 	[_augment_epsnet] Color 1: 1067
# [_augment_epsnet] Color 0 to add: 545
# [_augment_epsnet] Color 1 to add: 496
# Number of points in epsnet: 3126, time taken: 0.095278 seconds
# Success: True
# Running for n=4096, m=2048, eps=0.6, dim=4
# n: 4096, m: 2048, vc: 5, epsilon: 0.6, number of heavy ranges: 966
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 153
# 	[_augment_epsnet] Color 1: 163
# [_augment_epsnet] Color 0 to add: 84
# [_augment_epsnet] Color 1 to add: 74
# Number of points in epsnet: 474, time taken: 0.008867 seconds
# Success: True
# Running for n=4096, m=2048, eps=0.6, dim=8
# n: 4096, m: 2048, vc: 9, epsilon: 0.6, number of heavy ranges: 973
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 278
# 	[_augment_epsnet] Color 1: 291
# [_augment_epsnet] Color 0 to add: 148
# [_augment_epsnet] Color 1 to add: 135
# Number of points in epsnet: 852, time taken: 0.015332 seconds
# Success: True
# Running for n=4096, m=2048, eps=0.6, dim=16
# n: 4096, m: 2048, vc: 17, epsilon: 0.6, number of heavy ranges: 1006
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 535
# 	[_augment_epsnet] Color 1: 539
# [_augment_epsnet] Color 0 to add: 270
# [_augment_epsnet] Color 1 to add: 266
# Number of points in epsnet: 1610, time taken: 0.024935 seconds
# Success: True
# Running for n=4096, m=2048, eps=0.6, dim=32
# n: 4096, m: 2048, vc: 33, epsilon: 0.6, number of heavy ranges: 1050
# [build_fair_epsnet_sample] epsnet size m: 2085, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 1089
# 	[_augment_epsnet] Color 1: 996
# [_augment_epsnet] Color 0 to add: 474
# [_augment_epsnet] Color 1 to add: 567
# Number of points in epsnet: 3126, time taken: 0.041780 seconds
# Success: True
# Running for n=4096, m=4096, eps=0.6, dim=4
# n: 4096, m: 4096, vc: 5, epsilon: 0.6, number of heavy ranges: 1917
# [build_fair_epsnet_sample] epsnet size m: 316, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 153
# 	[_augment_epsnet] Color 1: 163
# [_augment_epsnet] Color 0 to add: 84
# [_augment_epsnet] Color 1 to add: 74
# Number of points in epsnet: 474, time taken: 0.009240 seconds
# Success: True
# Running for n=4096, m=4096, eps=0.6, dim=8
# n: 4096, m: 4096, vc: 9, epsilon: 0.6, number of heavy ranges: 1986
# [build_fair_epsnet_sample] epsnet size m: 569, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 281
# 	[_augment_epsnet] Color 1: 288
# [_augment_epsnet] Color 0 to add: 145
# [_augment_epsnet] Color 1 to add: 138
# Number of points in epsnet: 852, time taken: 0.015435 seconds
# Success: True
# Running for n=4096, m=4096, eps=0.6, dim=16
# n: 4096, m: 4096, vc: 17, epsilon: 0.6, number of heavy ranges: 1975
# [build_fair_epsnet_sample] epsnet size m: 1074, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 527
# 	[_augment_epsnet] Color 1: 547
# [_augment_epsnet] Color 0 to add: 278
# [_augment_epsnet] Color 1 to add: 258
# Number of points in epsnet: 1610, time taken: 0.025289 seconds
# Success: True
# Running for n=4096, m=4096, eps=0.6, dim=32
# n: 4096, m: 4096, vc: 33, epsilon: 0.6, number of heavy ranges: 2059
# [build_fair_epsnet_sample] epsnet size m: 2085, v: 1.5
# [_augment_epsnet] epsnet colors count:
# 	[_augment_epsnet] Color 0: 1011
# 	[_augment_epsnet] Color 1: 1074
# [_augment_epsnet] Color 0 to add: 552
# [_augment_epsnet] Color 1 to add: 489
# Number of points in epsnet: 3126, time taken: 0.041660 seconds
# Success: True

# %%
# result.to_csv("dp_fair_epsnet_halfspace_sample.csv", index=False)

# %% [markdown]
# Sketch and merge:

# %%
def report_fair_epsnet_sketch_merge(n, m, eps, ratios, c1, dim):
    success_prob = 0.9
    
    
    color_counts = []
    for ratio in ratios:
        color_counts.append(int(n * ratio))
    
    points = []
    for i, count in enumerate(color_counts):
        points += [Point(point=[random.uniform(0, 1), random.uniform(0, 1)], color=i) for _ in range(count)]
    
    ranges = []
    for _ in range(m):
        # Generate a random normal vector in R^d
        normal = [random.uniform(-1, 1) for _ in range(dim)]
        
        # Calculate the range of possible dot products with the [0, 1]^d hypercube
        min_dot = sum(min(0, n) for n in normal)  # Minimum dot product with [0, 1]^d
        max_dot = sum(max(0, n) for n in normal)  # Maximum dot product with [0, 1]^d
        
        # Choose an offset within the range [min_dot, max_dot] to ensure intersection
        offset = random.uniform(min_dot, max_dot)
        
        # Create a HalfspaceRange object
        halfspace = HalfspaceRange(normal=normal, offset=offset)
        ranges.append(halfspace)
        
    rangespace = get_range_space(points, ranges)
    vc = dim + 1

    heavy_ranges = []
    for r in rangespace:
        if len(r) >= n * eps:
            heavy_ranges.append(r)
            
    print(f"n: {n}, m: {m}, vc: {vc}, epsilon: {eps}, number of heavy ranges: {len(heavy_ranges)}")

    # for _ in range(10):
    start = time.time()
    epsnet = build_fair_epsnet_sketch_merge(
        points=points,
        rangespace=rangespace,
        vc=vc,
        epsilon=eps,
        fairconfig=FairConfig(k=len(ratios), fairness=FairnessMeasure.DP),
        c1=0,
        c2=c1
    )
    end = time.time()

    print(f"Number of points in epsnet: {len(epsnet)}, time taken: {end - start:.6f} seconds")

    success = is_fair_epsnet(epsnet=epsnet, rangespace=rangespace, epsilon=eps, points=points)
    print(f"Success: {success}")  # Verify the eps-net
    
    return (n, m, 
            success_prob, 
            eps, 
            end - start, 
            success, 
            len(heavy_ranges), 
            len([p for p in epsnet if p.color == 0]), len([p for p in epsnet if p.color == 1]),
            len(ratios), # k
            ratios,
            [len([p for p in epsnet if p.color == i]) for i in range(len(ratios))], # color counts
            )

# %%
# n_values = [2**10]
# m_values = [2**9, 2**10, 2**11, 2**12]
# eps_values = [0.6]
# dims = [4, 8, 16, 32]
rates = [
    [0.5, 0.5]
]

n_values = [2**10]#, 2**12]
m_values = [2**9, 2**10, 2**11, 2**12]
dims = [4, 8, 16, 32]
eps_values = [0.9]

aggregated_results = {
    "n": [],
    "m": [],
    "prob": [],
    "eps": [],
    "time": [],
    "success": [],
    "heavy_ranges": [],
    "tries": [],
    "red_points": [],
    "blue_points": [],
    "k": [],
    "ratios": [],
    "counts": [],
    "dim": []
}

for n in n_values:
    for m in m_values:
        for eps in eps_values:
            for dim in dims:
                ratio = rates[0]
                tries = 20
                print(f"Running for n={n}, m={m}, eps={eps}, dim={dim}")
                result = report_fair_epsnet_sketch_merge(n, m, eps, ratio, c1=1, dim=dim)
                while not result[5] and tries > 0:
                    print("Retrying...")
                    result = report_fair_epsnet_sketch_merge(n, m, eps, ratio, c1=1, dim=dim)
                    tries -= 1
                
                aggregated_results["n"].append(result[0])
                aggregated_results["m"].append(result[1])
                aggregated_results["prob"].append(result[2])
                aggregated_results["eps"].append(result[3])
                aggregated_results["time"].append(result[4])
                aggregated_results["success"].append(result[5])
                aggregated_results["heavy_ranges"].append(result[6])
                aggregated_results["tries"].append(10 - tries)
                aggregated_results["red_points"].append(result[7])
                aggregated_results["blue_points"].append(result[8])
                aggregated_results["k"].append(result[9])
                aggregated_results["ratios"].append(result[10])
                aggregated_results["counts"].append(result[11])
                aggregated_results["dim"].append(dim)

result = pd.DataFrame(aggregated_results)
# Out:
# Running for n=1024, m=512, eps=0.9, dim=4
# n: 1024, m: 512, vc: 5, epsilon: 0.9, number of heavy ranges: 189
# [build_fair_epsnet_sketch_merge] epsnet size m: 185
# [build_fair_epsnet_sketch_merge] partition size p: 256
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 2 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 256 / 256
#
# Number of points in epsnet: 256, time taken: 30.329808 seconds
# Success: True
# Running for n=1024, m=512, eps=0.9, dim=8
# n: 1024, m: 512, vc: 9, epsilon: 0.9, number of heavy ranges: 213
# [build_fair_epsnet_sketch_merge] epsnet size m: 333
# [build_fair_epsnet_sketch_merge] partition size p: 512
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 512 / 512
#
# Number of points in epsnet: 512, time taken: 18.430717 seconds
# Success: True
# Running for n=1024, m=512, eps=0.9, dim=16
# n: 1024, m: 512, vc: 17, epsilon: 0.9, number of heavy ranges: 241
# [build_fair_epsnet_sketch_merge] epsnet size m: 628
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000038 seconds
# Success: True
# Running for n=1024, m=512, eps=0.9, dim=32
# n: 1024, m: 512, vc: 33, epsilon: 0.9, number of heavy ranges: 246
# [build_fair_epsnet_sketch_merge] epsnet size m: 1024
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000056 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.9, dim=4
# n: 1024, m: 1024, vc: 5, epsilon: 0.9, number of heavy ranges: 366
# [build_fair_epsnet_sketch_merge] epsnet size m: 185
# [build_fair_epsnet_sketch_merge] partition size p: 256
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 2 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 256 / 256
#
# Number of points in epsnet: 256, time taken: 61.220508 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.9, dim=8
# n: 1024, m: 1024, vc: 9, epsilon: 0.9, number of heavy ranges: 433
# [build_fair_epsnet_sketch_merge] epsnet size m: 333
# [build_fair_epsnet_sketch_merge] partition size p: 512
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 512 / 512
#
# Number of points in epsnet: 512, time taken: 40.134254 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.9, dim=16
# n: 1024, m: 1024, vc: 17, epsilon: 0.9, number of heavy ranges: 480
# [build_fair_epsnet_sketch_merge] epsnet size m: 628
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000044 seconds
# Success: True
# Running for n=1024, m=1024, eps=0.9, dim=32
# n: 1024, m: 1024, vc: 33, epsilon: 0.9, number of heavy ranges: 482
# [build_fair_epsnet_sketch_merge] epsnet size m: 1024
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000045 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.9, dim=4
# n: 1024, m: 2048, vc: 5, epsilon: 0.9, number of heavy ranges: 741
# [build_fair_epsnet_sketch_merge] epsnet size m: 185
# [build_fair_epsnet_sketch_merge] partition size p: 256
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 2 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 256 / 256
#
# Number of points in epsnet: 256, time taken: 125.592146 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.9, dim=8
# n: 1024, m: 2048, vc: 9, epsilon: 0.9, number of heavy ranges: 849
# [build_fair_epsnet_sketch_merge] epsnet size m: 333
# [build_fair_epsnet_sketch_merge] partition size p: 512
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 512 / 512
#
# Number of points in epsnet: 512, time taken: 75.991258 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.9, dim=16
# n: 1024, m: 2048, vc: 17, epsilon: 0.9, number of heavy ranges: 956
# [build_fair_epsnet_sketch_merge] epsnet size m: 628
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000044 seconds
# Success: True
# Running for n=1024, m=2048, eps=0.9, dim=32
# n: 1024, m: 2048, vc: 33, epsilon: 0.9, number of heavy ranges: 969
# [build_fair_epsnet_sketch_merge] epsnet size m: 1024
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000043 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.9, dim=4
# n: 1024, m: 4096, vc: 5, epsilon: 0.9, number of heavy ranges: 1451
# [build_fair_epsnet_sketch_merge] epsnet size m: 185
# [build_fair_epsnet_sketch_merge] partition size p: 256
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 2 / 2 of total nodes: 4
# [_greedy_discrepancy_halving] counter: 256 / 256
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 256 / 256
#
# Number of points in epsnet: 256, time taken: 242.921528 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.9, dim=8
# n: 1024, m: 4096, vc: 9, epsilon: 0.9, number of heavy ranges: 1742
# [build_fair_epsnet_sketch_merge] epsnet size m: 333
# [build_fair_epsnet_sketch_merge] partition size p: 512
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
# [_sketch_merge] pair: 1 / 1 of total nodes: 2
# [_greedy_discrepancy_halving] counter: 512 / 512
#
# Number of points in epsnet: 512, time taken: 156.320740 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.9, dim=16
# n: 1024, m: 4096, vc: 17, epsilon: 0.9, number of heavy ranges: 1833
# [build_fair_epsnet_sketch_merge] epsnet size m: 628
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000047 seconds
# Success: True
# Running for n=1024, m=4096, eps=0.9, dim=32
# n: 1024, m: 4096, vc: 33, epsilon: 0.9, number of heavy ranges: 2007
# [build_fair_epsnet_sketch_merge] epsnet size m: 1024
# [build_fair_epsnet_sketch_merge] partition size p: 1024
# [build_fair_epsnet_sketch_merge] Starting sketch-and-merge...
#
# Number of points in epsnet: 1024, time taken: 0.000048 seconds
# Success: True

# %%
# result.to_csv("dp_fair_epsnet_halfspace_sketch_merge.csv", index=False)
